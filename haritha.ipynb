# %%
)
cursor=connection.commit
sql_drop_table = "DROP TABLE IF EXISTS `restaurants_data`;"
sql_create_table = """
CREATE TABLE `restaurants_data` (
    `name` VARCHAR(255),
    `online_order` VARCHAR(255),
    `book_table` VARCHAR(255),
    `rate` FLOAT,ubereats,py
    `votes` INT,
    `phone` VARCHAR(255),
    `location` VARCHAR(255),
    `rest_type` VARCHAR(255),
    `dish_liked` TEXT,
    `cuisines` TEXT,
    `approx_cost_for_two_people` FLOAT,
    `listed_in_type` VARCHAR(255),
    `listed_in_city` VARCHAR(255),
    `price_category` VARCHAR(255)
);
"""
try:
    cursor.execute(sql_drop_table)
    cursor.execute(sql_create_table)
    connection.commit()
    print("Table 'restaurants_data' created successfully.")
except Exception as e:
    connection.rollback()
    print(f"An error occurred: {e}")
finally:
    # It's good practice to close the cursor and connection when done
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: You must give at least one requirement to install (see "pip help install")
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 4
#       2 import pymysql
#       3 import certifi  # Add this import
# ----> 4 connection = pymysql.connect(
#       5     host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
#       6     port=4000,
#       7     user="2LQdqxSJhDf5xi1.root",
#       8     password="Aj8ylybqeyjfdfcj",
#       9     database="eatdata",
#      10     ssl_ca=certifi.where()
#      11 )
#      12 cursor=connection.commit
#      13 sql_drop_table = "DROP TABLE IF EXISTS `restaurants_data`;"
#
# ...
